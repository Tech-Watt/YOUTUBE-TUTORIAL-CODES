# %% [markdown]
# Mounting the drive to google colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Checking for gpu acess

# %%
# !nvidia-smi

# %% [markdown]
# Check your current working directory

# %%
import os
directory = os.getcwd()
print(directory)

# %% [markdown]
# Install Yolov8

# %%
# !pip install ultralytics

# %% [markdown]
# Importing Yolo and display from IPython

# %%
from ultralytics import YOLO
from IPython.display import display,Image

# %% [markdown]
# Run a test on an image

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/drive/MyDrive/cars.jpg'

# %% [markdown]
# Acessing result at runs/detect/predict

# %%
image ='runs/detect/predict2/cars.jpg' 
Image(filename=image,height=500)

# %% [markdown]
# Second method of runing a test using the Python SDK

# %%
model = YOLO(f'{directory}/yolov8n.pt')
result = model.predict(source = '/content/drive/MyDrive/cars.jpg',conf =0.25)

# %% [markdown]
# Output will be stored in runs/detect/predict directory

# %%
image ='runs/detect/predict2/cars.jpg' 
Image(filename=image,height=500)

# %% [markdown]
# Test on a video file

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/drive/MyDrive/cars.jpg'
